# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets

# %%
data=pd.read_csv(r"C:\Users\RAHUL KRISHNA\Desktop\Weather Prediction Data\Cleaning & Preprocessing\Analysis.csv")

# %%
data
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0      2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1      2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2      2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3      2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4      2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                          ...            ...         ...              ...
# 96448  2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449  2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450  2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451  2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452  2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
sns.barplot(x=data['year'],y=data['Precip Type'],estimator=sum)
# Out:
# <Axes: xlabel='year', ylabel='Precip Type'>

# %%
sns.boxplot(x=data['year'],y=data['Precip Type'])
# Out:
# <Axes: xlabel='year', ylabel='Precip Type'>

# %%
sns.scatterplot(y=data['year'],x=data['Precip Type'])
# Out:
# <Axes: xlabel='Precip Type', ylabel='year'>

# %%
sns.lineplot(x=data['year'],y=data['Humidity'])
# Out:
# <Axes: xlabel='year', ylabel='Humidity'>

# %%
sns.lineplot(x=data['year'],y=data['Precip Type'])
# Out:
# <Axes: xlabel='year', ylabel='Precip Type'>

# %%
sns.histplot(x=data['year'],y=data['Humidity'])
# Out:
# <Axes: xlabel='year', ylabel='Humidity'>

# %%
sns.barplot(x=data['Temperature (C)'],y=data['month_name'],estimator=len)
# Out:
# <Axes: xlabel='Temperature (C)', ylabel='month_name'>

# %%
sns.barplot(x='year',y='Summary',data=rain,estimator=len)
# Out:
# <Axes: xlabel='year', ylabel='Summary'>

# %%
rain=data[data['Precip Type']=='rain']

# %%
sns.barplot(x='year',y='Summary',data=rain,estimator=len)
sns.lineplot(x='Visibility',y='Humidity',estimator=sum)
sns.boxplot(x='month',y='Summary')
sns.scatterplot(x='month',y='Temperature (C)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 2
#       1 sns.barplot(x='year',y='Summary',data=rain,estimator=len)
# ----> 2 sns.lineplot(x='Visibility',y='Humidity',estimator=sum)
#       3 sns.boxplot(x='month',y='Summary')
#       4 sns.scatterplot(x='month',y='Temperature (C)')
#
# File c:\Users\RAHUL KRISHNA\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
# ...
